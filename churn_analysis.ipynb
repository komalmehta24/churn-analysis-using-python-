# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\KOMAL\Downloads\Telegram Desktop\telco_churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)*100
# Out:
# Churn
# 0    73.421502
# 1    26.578498
# Name: proportion, dtype: float64

# %%
df["TotalCharges"] = pd.to_numeric(df['TotalCharges'] , errors = "coerce")

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'newCustomers'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df.shape
# Out:
# (7032, 21)

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
x=  df["Churn"].value_counts().values
y = df["Churn"].value_counts().index

# %%
plt.figure(figsize=(3,4))
plt.bar(y, x , width=0.3)
plt.title("churned or not")
plt.show()

# %%
df["Churn"] =df["Churn"].map({'No':0,"Yes":1})

# %%
revenue_loss = df[df['Churn']==1]['MonthlyCharges'].sum()*12
revenue_loss
# Out:
# np.float64(1669570.2000000002)

# %%
total_loss = df[df['Churn']==1]['TotalCharges'].sum()*12
total_loss
# Out:
# np.float64(34355122.8)

# %%
df.groupby('Churn')[['tenure', 'MonthlyCharges', 'TotalCharges']].mean()
# Out:
#           tenure  MonthlyCharges  TotalCharges
# Churn
# 0      37.650010       61.307408   2555.344141
# 1      17.979133       74.441332   1531.796094

# %%
df['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1604
# Bank transfer (automatic)    1542
# Credit card (automatic)      1521
# Name: count, dtype: int64

# %%
df.groupby('SeniorCitizen')['Churn'].value_counts(normalize=True)*100
# Out:
# SeniorCitizen  Churn
# 0              1        76.349745
#                0        23.650255
# 1              1        58.318739
#                0        41.681261
# Name: proportion, dtype: float64

# %%
df.groupby('PaymentMethod')['Churn'].value_counts()
# Out:
# PaymentMethod              Churn
# Bank transfer (automatic)  0        1284
#                            1         258
# Credit card (automatic)    0        1289
#                            1         232
# Electronic check           0        1294
#                            1        1071
# Mailed check               0        1296
#                            1         308
# Name: count, dtype: int64

# %%
df.groupby('PaperlessBilling')['Churn'].value_counts()
# Out:
# PaperlessBilling  Churn
# No                0        2395
#                   1         469
# Yes               0        2768
#                   1        1400
# Name: count, dtype: int64

# %%
df.groupby('Contract')['Churn'].value_counts()
# Out:
# Contract        Churn
# Month-to-month  0        2220
#                 1        1655
# One year        0        1306
#                 1         166
# Two year        0        1637
#                 1          48
# Name: count, dtype: int64

# %%
df.groupby('Churn')['MonthlyCharges'].mean()
# Out:
# Churn
# 0    61.307408
# 1    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby('Churn')['tenure'].mean()
# Out:
# Churn
# 0    37.650010
# 1    17.979133
# Name: tenure, dtype: float64

# %%
df.groupby('InternetService')['Churn'].value_counts()
# Out:
# InternetService  Churn
# DSL              0        1957
#                  1         459
# Fiber optic      0        1799
#                  1        1297
# No               0        1407
#                  1         113
# Name: count, dtype: int64

# %%
df.groupby("gender")["Churn"].value_counts()
# Out:
# gender  Churn
# Female  0        2544
#         1         939
# Male    0        2619
#         1         930
# Name: count, dtype: int64

# %%
df.groupby(["Contract" , "PaymentMethod"])["Churn"].value_counts()
# Out:
# Contract        PaymentMethod              Churn
# Month-to-month  Bank transfer (automatic)  0        388
#                                            1        201
#                 Credit card (automatic)    0        365
#                                            1        178
#                 Electronic check           1        994
#                                            0        856
#                 Mailed check               0        611
#                                            1        282
# One year        Bank transfer (automatic)  0        353
#                                            1         38
#                 Credit card (automatic)    0        357
#                                            1         41
#                 Electronic check           0        283
#                                            1         64
#                 Mailed check               0        313
#                                            1         23
# ...

# %%
df['PaperlessBilling'].value_counts()
# Out:
# PaperlessBilling
# Yes    4168
# No     2864
# Name: count, dtype: int64

# %%
df.groupby('PaperlessBilling')['Churn'].value_counts()
# Out:
# PaperlessBilling  Churn
# No                0        2395
#                   1         469
# Yes               0        2768
#                   1        1400
# Name: count, dtype: int64

# %%
df.groupby(['Contract'])['Churn'].value_counts()
# Out:
# Contract        Churn
# Month-to-month  0        2220
#                 1        1655
# One year        0        1306
#                 1         166
# Two year        0        1637
#                 1          48
# Name: count, dtype: int64

# %%
df.groupby(['Contract', 'PaymentMethod'])['Churn'].value_counts()
# Out:
# Contract        PaymentMethod              Churn
# Month-to-month  Bank transfer (automatic)  0        388
#                                            1        201
#                 Credit card (automatic)    0        365
#                                            1        178
#                 Electronic check           1        994
#                                            0        856
#                 Mailed check               0        611
#                                            1        282
# One year        Bank transfer (automatic)  0        353
#                                            1         38
#                 Credit card (automatic)    0        357
#                                            1         41
#                 Electronic check           0        283
#                                            1         64
#                 Mailed check               0        313
#                                            1         23
# ...

# %%
df["newCustomers"] = df["tenure"] <12

# %%
df.groupby('newCustomers')['Churn'].value_counts()
# Out:
# newCustomers  Churn
# False         0        4104
#               1         870
# True          0        1059
#               1         999
# Name: count, dtype: int64

# %%
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title('Churn by Contract Type')
plt.show()

# %%
sns.countplot(x='SeniorCitizen', hue='Churn', data=df)
plt.title('Churn by Senior Citizen Status')
plt.show()

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title('Monthly Charges vs Churn')
plt.show()

# %%
sns.countplot(x='PaymentMethod', hue='Churn', data=df)
plt.xticks(rotation=50)
plt.title('Churn by Payment Method')
plt.show()

# %%
sns.countplot(x = 'newCustomers', hue="Churn", data=df)
# Out:
# <Axes: xlabel='newCustomers', ylabel='count'>

# %%
df.groupby('Churn')['MonthlyCharges'].mean()
# Out:
# Churn
# 0    61.307408
# 1    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
pd.crosstab(df['InternetService'], df['Churn'], normalize='index')
# Out:
# Churn                   0         1
# InternetService
# DSL              0.810017  0.189983
# Fiber optic      0.581072  0.418928
# No               0.925658  0.074342

# %%
pd.crosstab(df['TechSupport'], df['Churn'], normalize='index')
# Out:
# Churn                       0         1
# TechSupport
# No                   0.583525  0.416475
# No internet service  0.925658  0.074342
# Yes                  0.848039  0.151961

# %%
  pd.crosstab(df['MultipleLines'], df['Churn'], normalize='index')
# Out:
# Churn                    0         1
# MultipleLines
# No                0.749188  0.250812
# No phone service  0.750000  0.250000
# Yes               0.713515  0.286485

# %%
pd.crosstab(df['StreamingTV'], df['Churn'], normalize='index')
# Out:
# Churn                       0         1
# StreamingTV
# No                   0.664649  0.335351
# No internet service  0.925658  0.074342
# Yes                  0.698853  0.301147

# %%
pd.crosstab(df['StreamingMovies'], df['Churn'], normalize='index')
# Out:
# Churn                       0         1
# StreamingMovies
# No                   0.662711  0.337289
# No internet service  0.925658  0.074342
# Yes                  0.700476  0.299524

# %%
pd.crosstab(df['OnlineSecurity'], df['Churn'], normalize='index')
# Out:
# Churn                       0         1
# OnlineSecurity
# No                   0.582213  0.417787
# No internet service  0.925658  0.074342
# Yes                  0.853598  0.146402

# %%
pd.crosstab(df['OnlineBackup'], df['Churn'], normalize='index')
# Out:
# Churn                       0         1
# OnlineBackup
# No                   0.600583  0.399417
# No internet service  0.925658  0.074342
# Yes                  0.784330  0.215670

# %%
pd.crosstab(df['DeviceProtection'], df['Churn'], normalize='index')
# Out:
# Churn                       0         1
# DeviceProtection
# No                   0.608597  0.391403
# No internet service  0.925658  0.074342
# Yes                  0.774607  0.225393
