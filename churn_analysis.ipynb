# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\KOMAL\Downloads\telco.csv")
df.head()
# Out:
#    Unnamed: 0  customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0           0  7590-VHVEG  Female            No     Yes         No       1
# 1           1  5575-GNVDE    Male            No      No         No      34
# 2           2  3668-QPYBK    Male            No      No         No       2
# 3           3  7795-CFOCW    Male            No      No         No      45
# 4           4  9237-HQITU  Female            No      No         No       2
#
#   PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# 0           No  No phone service             DSL  ...               No
# 1          Yes                No             DSL  ...              Yes
# 2          Yes                No             DSL  ...               No
# 3           No  No phone service             DSL  ...              Yes
# 4          Yes                No     Fiber optic  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 7038        7038  6840-RESVB    Male            No     Yes        Yes      24
# 7039        7039  2234-XADUH  Female            No     Yes        Yes      72
# 7040        7040  4801-JZAZL  Female            No     Yes        Yes      11
# 7041        7041  8361-LTMKD    Male           Yes     Yes         No       4
# 7042        7042  3186-AJIEK    Male            No      No         No      66
#
#      PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# 7038          Yes               Yes             DSL  ...              Yes
# 7039          Yes               Yes     Fiber optic  ...              Yes
# 7040           No  No phone service             DSL  ...               No
# 7041          Yes               Yes     Fiber optic  ...               No
# 7042          Yes                No     Fiber optic  ...              Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7043 non-null   int64
#  1   customerID        7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   object
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0       tenure  MonthlyCharges
# count  7043.000000  7043.000000     7043.000000
# mean   3521.000000    32.371149       64.761692
# std    2033.283305    24.559481       30.090047
# min       0.000000     0.000000       18.250000
# 25%    1760.500000     9.000000       35.500000
# 50%    3521.000000    29.000000       70.350000
# 75%    5281.500000    55.000000       89.850000
# max    7042.000000    72.000000      118.750000

# %%
df["Churn"].value_counts()
# Out:
# Churn
# Stayed     5174
# Churned    1869
# Name: count, dtype: int64

# %%
df["TotalCharges"] = pd.to_numeric(df['TotalCharges'] , errors = "coerce" )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7043 non-null   int64
#  1   customerID        7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   object
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df["Churn"].value_counts(normalize=True)*100
# Out:
# Churn
# Stayed     73.421502
# Churned    26.578498
# Name: proportion, dtype: float64

# %%
x=  df["Churn"].value_counts().values
y = df["Churn"].value_counts().index

# %%
plt.figure(figsize=(3,4))
plt.bar(y, x , width=0.3)
plt.title("churned or not ")
plt.show()

# %%
sns.barplot(x = 'Churn' , y = 'tenure' , data = df , width=0.3)
plt.title("Tenure vs Churn")
plt.show()

# %%
sns.barplot(x='Churn', y='MonthlyCharges', data=df , width=0.3)
plt.title("Monthly Charges vs Churn")
plt.show()

# %%
df.groupby('Churn')[['tenure', 'MonthlyCharges', 'TotalCharges']].mean()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# Churn
# Churned  17.979133       74.441332   1531.796094
# Stayed   37.650010       61.307408   2555.344141

# %%
df['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1604
# Bank transfer (automatic)    1542
# Credit card (automatic)      1521
# Name: count, dtype: int64

# %%
df.groupby('PaymentMethod')[['Churn']].value_counts(normalize=True).mul(100).rename('churn_percentage').reset_index()
# Out:
#                PaymentMethod    Churn  churn_percentage
# 0  Bank transfer (automatic)   Stayed         83.268482
# 1  Bank transfer (automatic)  Churned         16.731518
# 2    Credit card (automatic)   Stayed         84.746877
# 3    Credit card (automatic)  Churned         15.253123
# 4           Electronic check   Stayed         54.714588
# 5           Electronic check  Churned         45.285412
# 6               Mailed check   Stayed         80.798005
# 7               Mailed check  Churned         19.201995

# %%
df.groupby('SeniorCitizen')['Churn'].value_counts(normalize=True)*100
# Out:
# SeniorCitizen  Churn
# No             Stayed     76.349745
#                Churned    23.650255
# Yes            Stayed     58.318739
#                Churned    41.681261
# Name: proportion, dtype: float64

# %%
df.groupby('PaymentMethod')['Churn'].value_counts(normalize=True)*100
# Out:
# PaymentMethod              Churn
# Bank transfer (automatic)  Stayed     83.268482
#                            Churned    16.731518
# Credit card (automatic)    Stayed     84.746877
#                            Churned    15.253123
# Electronic check           Stayed     54.714588
#                            Churned    45.285412
# Mailed check               Stayed     80.798005
#                            Churned    19.201995
# Name: proportion, dtype: float64

# %%
df.groupby('PaperlessBilling')['Churn'].value_counts(normalize=True) * 100
# Out:
# PaperlessBilling  Churn
# No                Stayed     83.624302
#                   Churned    16.375698
# Yes               Stayed     66.410749
#                   Churned    33.589251
# Name: proportion, dtype: float64

# %%
df.groupby('Contract')['Churn'].value_counts(normalize=True) * 100
# Out:
# Contract        Churn
# Month-to-month  Stayed     57.290323
#                 Churned    42.709677
# One year        Stayed     88.722826
#                 Churned    11.277174
# Two year        Stayed     97.151335
#                 Churned     2.848665
# Name: proportion, dtype: float64

# %%
df.groupby('Churn')['MonthlyCharges'].mean()
# Out:
# Churn
# Churned    74.441332
# Stayed     61.307408
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby('Churn')['tenure'].mean()
# Out:
# Churn
# Churned    17.979133
# Stayed     37.650010
# Name: tenure, dtype: float64

# %%
df.groupby('InternetService')['Churn'].value_counts(normalize=True)*100
# Out:
# InternetService  Churn
# DSL              Stayed     81.098072
#                  Churned    18.901928
# Fiber optic      Stayed     58.107235
#                  Churned    41.892765
# No               Stayed     92.565789
#                  Churned     7.434211
# dsl              Stayed     73.333333
#                  Churned    26.666667
# Name: proportion, dtype: float64

# %%
df.groupby("gender")["Churn"].value_counts(normalize=True)*100
# Out:
# gender  Churn
# Female  Stayed     73.040482
#         Churned    26.959518
# Male    Stayed     73.795435
#         Churned    26.204565
# Name: proportion, dtype: float64

# %%
df.groupby(["Contract" , "PaymentMethod"])["Churn"].value_counts(normalize=True)*100
# Out:
# Contract        PaymentMethod              Churn
# Month-to-month  Bank transfer (automatic)  Stayed     65.874363
#                                            Churned    34.125637
#                 Credit card (automatic)    Stayed     67.219153
#                                            Churned    32.780847
#                 Electronic check           Churned    53.729730
#                                            Stayed     46.270270
#                 Mailed check               Stayed     68.421053
#                                            Churned    31.578947
# One year        Bank transfer (automatic)  Stayed     90.281330
#                                            Churned     9.718670
#                 Credit card (automatic)    Stayed     89.698492
#                                            Churned    10.301508
#                 Electronic check           Stayed     81.556196
#                                            Churned    18.443804
# ...

# %%
df['PaperlessBilling'].value_counts()
# Out:
# PaperlessBilling
# Yes    4168
# No     2864
# Name: count, dtype: int64

# %%
df.groupby('PaperlessBilling')['Churn'].value_counts(normalize=True) * 100
# Out:
# PaperlessBilling  Churn
# No                Stayed     83.624302
#                   Churned    16.375698
# Yes               Stayed     66.410749
#                   Churned    33.589251
# Name: proportion, dtype: float64

# %%
df.groupby(['Contract', 'PaperlessBilling'])['Churn'].value_counts(normalize=True) * 100
# Out:
# Contract        PaperlessBilling  Churn
# Month-to-month  No                Stayed     68.502715
#                                   Churned    31.497285
#                 Yes               Stayed     51.701469
#                                   Churned    48.298531
# One year        No                Stayed     92.867756
#                                   Churned     7.132244
#                 Yes               Stayed     85.231539
#                                   Churned    14.768461
# Two year        No                Stayed     98.337029
#                                   Churned     1.662971
#                 Yes               Stayed     95.785441
#                                   Churned     4.214559
# Name: proportion, dtype: float64

# %%
df.groupby(['Contract', 'PaymentMethod'])['Churn'] \
  .value_counts(normalize=True) * 100
# Out:
# Contract        PaymentMethod              Churn
# Month-to-month  Bank transfer (automatic)  Stayed     65.874363
#                                            Churned    34.125637
#                 Credit card (automatic)    Stayed     67.219153
#                                            Churned    32.780847
#                 Electronic check           Churned    53.729730
#                                            Stayed     46.270270
#                 Mailed check               Stayed     68.421053
#                                            Churned    31.578947
# One year        Bank transfer (automatic)  Stayed     90.281330
#                                            Churned     9.718670
#                 Credit card (automatic)    Stayed     89.698492
#                                            Churned    10.301508
#                 Electronic check           Stayed     81.556196
#                                            Churned    18.443804
# ...

# %%
df["newCustomers"] = df["tenure"] <12

# %%
df.groupby('newCustomers')['Churn'].value_counts(normalize=True) * 100
# Out:
# newCustomers  Churn
# False         Stayed     82.509047
#               Churned    17.490953
# True          Stayed     51.457726
#               Churned    48.542274
# Name: proportion, dtype: float64

# %%
df.groupby('Churn').agg({'tenure' :'mean',
                        'MonthlyCharges': 'mean',
                        'customerID': 'count'})
# Out:
#             tenure  MonthlyCharges  customerID
# Churn
# Churned  17.979133       74.441332        1869
# Stayed   37.650010       61.307408        5163

# %%
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title('Churn by Contract Type')
plt.show()

# %%
sns.countplot(x='SeniorCitizen', hue='Churn', data=df)
plt.title('Churn by Senior Citizen Status')
plt.show()

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title('Monthly Charges vs Churn')
plt.show()

# %%
sns.countplot(x='PaymentMethod', hue='Churn', data=df)
plt.xticks(rotation=50)
plt.title('Churn by Payment Method')
plt.show()
